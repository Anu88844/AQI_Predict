# %%
#importing liabires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AQI = pd.read_csv("delhi_aqi.csv",index_col=0)
AQI
# Out:
#                           co     no     no2     o3     so2   pm2_5    pm10  \
# date
# 2020-11-25 01:00:00  2616.88   2.18   70.60  13.59   38.62  364.61  411.73
# 2020-11-25 02:00:00  3631.59  23.25   89.11   0.33   54.36  420.96  486.21
# 2020-11-25 03:00:00  4539.49  52.75  100.08   1.11   68.67  463.68  541.95
# 2020-11-25 04:00:00  4539.49  50.96  111.04   6.44   78.20  454.81  534.00
# 2020-11-25 05:00:00  4379.27  42.92  117.90  17.17   87.74  448.14  529.19
# ...                      ...    ...     ...    ...     ...     ...     ...
# 2023-01-24 04:00:00  1762.39   4.64   37.01  33.26   30.52  231.15  289.84
# 2023-01-24 05:00:00  1735.69   6.82   34.96  46.49   34.33  225.08  280.52
# 2023-01-24 06:00:00  1922.61   8.16   40.10  56.51   43.39  242.49  296.07
# 2023-01-24 07:00:00  1361.85   9.05   52.78  71.53  100.14  165.67  191.82
# 2023-01-24 08:00:00  1134.87   8.61   56.89  80.11  110.63  123.76  140.26
#
#                        nh3
# date
# ...

# %%
#Print Dataset_Head & Shape
print(AQI.head())
print(AQI.shape)
# Out:
#                           co     no     no2     o3    so2   pm2_5    pm10  \
# date
# 2020-11-25 01:00:00  2616.88   2.18   70.60  13.59  38.62  364.61  411.73
# 2020-11-25 02:00:00  3631.59  23.25   89.11   0.33  54.36  420.96  486.21
# 2020-11-25 03:00:00  4539.49  52.75  100.08   1.11  68.67  463.68  541.95
# 2020-11-25 04:00:00  4539.49  50.96  111.04   6.44  78.20  454.81  534.00
# 2020-11-25 05:00:00  4379.27  42.92  117.90  17.17  87.74  448.14  529.19
#
#                        nh3
# date
# 2020-11-25 01:00:00  28.63
# 2020-11-25 02:00:00  41.04
# 2020-11-25 03:00:00  49.14
# 2020-11-25 04:00:00  48.13
# 2020-11-25 05:00:00  46.61
# (18776, 8)

# %%
#measures the symmetry of a distribution in the dataset
AQI.pm2_5.skew()
# Out:
# 1.9494151536346735

# %%
AQI.co.unique()
# Out:
# array([ 2616.88,  3631.59,  4539.49,  4379.27,  3898.62,  1949.31,
#         1508.71,  1361.85,  1602.17,  2136.23,  2590.18,  3017.43,
#         3471.37,  4058.84,  3417.97,  2803.8 ,  2456.67,  2269.75,
#         2162.93,  2189.64,  2483.37,  3284.45,  3791.81,  3097.53,
#         2643.59,  2109.53,  1094.82,   894.55,   881.2 ,  1308.44,
#         2056.12,  2670.29,  3578.19,  3952.03,  4005.43,  3685.  ,
#         2723.69,  1695.63,  1134.87,   974.66,  1068.12,  1441.96,
#         1668.93,  1708.98,  1655.58,  1455.31,   947.95,   814.44,
#         1148.22,  2082.82,  2403.26,  2510.07,  2376.56,  2296.45,
#         2349.85,  1789.09,  1401.9 ,  1228.33,  1161.58,  1188.28,
#         1348.5 ,  1895.9 ,  1869.2 ,  1762.39,  1588.82,  1041.41,
#          867.84,  1735.69,  3124.24,  4272.46,  5340.58,  5767.82,
#         5073.55,  3524.78,  2002.72,  1562.12,  1428.6 ,  1321.79,
#         2429.96,  2830.51,  3150.94,  1121.52,  4112.24,  5714.42,
# ...

# %%
AQI.no2.unique()
# Out:
# array([ 70.6 ,  89.11, 100.08, 111.04, 117.9 , 105.56, 112.41, 109.67,
#         93.22,  94.59, 120.64,  98.71,  91.85,  83.63,  74.71,  65.8 ,
#         58.26,  53.47,  49.35,  46.61,  45.93,  51.41,  60.32,  71.29,
#         72.66,  67.86,  42.5 ,  44.55,  63.06, 106.93,  85.  ,  84.31,
#         78.14,  67.17,  54.84,  47.3 ,  39.76,  34.62,  33.59,  40.44,
#         55.52,  45.24,  33.24,  29.13,  30.5 , 104.19, 101.45,  87.05,
#         76.77,  75.4 ,  71.97,  58.95,  41.47,  32.56,  28.1 ,  26.05,
#         26.39,  32.22,  42.16,  37.7 ,  23.65,  19.71,  20.74, 116.53,
#        148.06, 150.8 , 142.57, 119.27, 102.82,  90.48,  56.21,  40.1 ,
#         35.99,  69.23,  79.51,  35.64,  36.67, 175.48, 180.96, 178.22,
#        157.65, 134.35,  86.37,  76.08,  87.74, 123.38, 153.54,  65.12,
#         42.84, 205.64, 200.15, 156.28, 137.09,  64.43,  57.58,  61.69,
#         80.88, 154.91,  50.04, 191.93, 216.6 , 213.86, 197.41, 115.16,
# ...

# %%
AQI['no2'].unique()
# Out:
# array([0.04685717, 0.04645554, 0.04819594, 0.04886533, 0.05020411,
#        0.04417961, 0.04284084, 0.04049798, 0.04016329, 0.03882451,
#        0.03748573, 0.04250614, 0.0562286 , 0.05488982, 0.05288166,
#        0.05221227, 0.05154289, 0.0508735 , 0.06091431, 0.05555921,
#        0.04618778, 0.03815512, 0.03079185, 0.02577144, 0.02342858,
#        0.02376328, 0.02677552, 0.03146124, 0.04351023, 0.044849  ,
#        0.04551839, 0.04752655, 0.03715104, 0.02744491, 0.02125307,
#        0.01757144, 0.01573062, 0.01556327, 0.01807348, 0.02208981,
#        0.03045716, 0.03547757, 0.03915921])

# %%
AQI['so2'].unique()
# Out:
# array([ 38.62,  54.36,  68.67,  78.2 ,  87.74, 101.09, 185.01, 217.44,
#        213.62, 152.59, 103.95,  82.02,  69.62,  65.8 ,  63.9 ,  59.61,
#         52.93,  42.92,  33.85,  30.99,  30.52,  31.47,  33.38,  39.1 ,
#         53.88,  73.43,  96.32, 108.72,  90.6 ,  83.92,  92.51, 100.14,
#         95.37,  84.88,  74.39,  64.85,  59.13,  51.98,  32.42,  26.7 ,
#         27.66,  29.56,  28.37,  28.13,  40.53,  47.21,  54.84,  61.99,
#         66.76,  48.16,  49.11,  51.02,  50.07,  49.59,  45.78,  42.44,
#         34.33,  25.03,  18.6 ,  16.45,  15.5 ,  17.41,  22.89,  46.25,
#         58.17,  41.49,  44.82,  61.04,  62.94,  67.71,  50.55,  45.3 ,
#         35.29,  23.84,  19.07,  16.93,  15.97,  15.74,  16.21,  20.5 ,
#         40.05,  75.34,  77.25,  99.18, 125.89, 143.05, 137.33, 118.26,
#         94.41,  58.65,  38.15,  36.72,  76.29,  97.28,  91.55, 106.81,
#        107.77,  41.96,  34.81,  88.69, 104.9 , 122.07,  89.65, 102.04,
# ...

# %%
AQI['pm10'].unique()
# Out:
# array([411.73, 486.21, 541.95, ..., 296.07, 191.82, 140.26])

# %%
sns.pairplot(AQI[['co','so2','no2','pm10','pm2_5']])

# %%
AQI.corr()
# Out:
#              co        no       no2        o3       so2     pm2_5      pm10  \
# co     1.000000  0.914129  0.764201 -0.402284  0.534227  0.936830  0.950218
# no     0.914129  1.000000  0.557712 -0.354905  0.498719  0.816441  0.829910
# no2    0.764201  0.557712  1.000000 -0.343609  0.710371  0.701840  0.711998
# o3    -0.402284 -0.354905 -0.343609  1.000000  0.013204 -0.286661 -0.294825
# so2    0.534227  0.498719  0.710371  0.013204  1.000000  0.488476  0.491889
# pm2_5  0.936830  0.816441  0.701840 -0.286661  0.488476  1.000000  0.989291
# pm10   0.950218  0.829910  0.711998 -0.294825  0.491889  0.989291  1.000000
# nh3    0.784951  0.724342  0.718399 -0.275983  0.628444  0.644446  0.686081
#
#             nh3
# co     0.784951
# no     0.724342
# no2    0.718399
# o3    -0.275983
# so2    0.628444
# pm2_5  0.644446
# pm10   0.686081
# nh3    1.000000

# %%
AQI.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_c8481_row0_col0, #T_c8481_row1_col1, #T_c8481_row2_col2, #T_c8481_row3_col3, #T_c8481_row4_col4, #T_c8481_row5_col5, #T_c8481_row6_col6, #T_c8481_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c8481_row0_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_c8481_row0_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_c8481_row0_col3, #T_c8481_row3_col0, #T_c8481_row3_col1, #T_c8481_row3_col2, #T_c8481_row3_col4, #T_c8481_row3_col5, #T_c8481_row3_col6, #T_c8481_row3_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c8481_row0_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c8481_row0_col5 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_c8481_row0_col6, #T_c8481_row6_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_c8481_row0_col7, #T_c8481_row2_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_c8481_row1_col0 {
# ...

# %%
plt.figure(figsize=(7,5))
sns.set_style('darkgrid')
sns.heatmap(data=AQI.corr(),
           annot=True,
           linewidth=0.5,
           cmap="GnBu")
plt.suptitle("Correlation Matrix of AQI")
plt.show()

# %%
AQI.describe()
# Out:
#                  co            no           no2            o3           so2  \
# count  18776.000000  18776.000000  18776.000000  18776.000000  18776.000000
# mean    2929.228628     33.660702     66.221299     60.346239     66.693633
# std     2854.523506     62.127118     48.527492     80.464932     49.439191
# min      260.350000      0.000000      4.280000      0.000000      5.250000
# 25%     1068.120000      0.680000     33.930000      0.340000     34.810000
# 50%     1842.500000      5.250000     54.150000     27.180000     52.930000
# 75%     3685.000000     35.760000     83.630000     92.980000     82.020000
# max    21148.680000    500.680000    460.620000    801.090000    579.830000
#
#               pm2_5          pm10           nh3
# count  18776.000000  18776.000000  18776.000000
# mean     238.130309    300.092966     25.109815
# std      226.533625    267.165827     26.402108
# min       11.830000     15.070000      0.000000
# ...

# %%
AQI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18776 entries, 2020-11-25 01:00:00 to 2023-01-24 08:00:00
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   co      18776 non-null  float64
#  1   no      18776 non-null  float64
#  2   no2     18776 non-null  float64
#  3   o3      18776 non-null  float64
#  4   so2     18776 non-null  float64
#  5   pm2_5   18776 non-null  float64
#  6   pm10    18776 non-null  float64
#  7   nh3     18776 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3+ MB

# %%
AQI.isna().sum().to_frame()
# Out:
#        0
# co     0
# no     0
# no2    0
# o3     0
# so2    0
# pm2_5  0
# pm10   0
# nh3    0

# %%
AQI.dropna(inplace=True)

# %%
AQI
# Out:
#                           co     no     no2     o3     so2   pm2_5    pm10  \
# date
# 2020-11-25 01:00:00  2616.88   2.18   70.60  13.59   38.62  364.61  411.73
# 2020-11-25 02:00:00  3631.59  23.25   89.11   0.33   54.36  420.96  486.21
# 2020-11-25 03:00:00  4539.49  52.75  100.08   1.11   68.67  463.68  541.95
# 2020-11-25 04:00:00  4539.49  50.96  111.04   6.44   78.20  454.81  534.00
# 2020-11-25 05:00:00  4379.27  42.92  117.90  17.17   87.74  448.14  529.19
# ...                      ...    ...     ...    ...     ...     ...     ...
# 2023-01-24 04:00:00  1762.39   4.64   37.01  33.26   30.52  231.15  289.84
# 2023-01-24 05:00:00  1735.69   6.82   34.96  46.49   34.33  225.08  280.52
# 2023-01-24 06:00:00  1922.61   8.16   40.10  56.51   43.39  242.49  296.07
# 2023-01-24 07:00:00  1361.85   9.05   52.78  71.53  100.14  165.67  191.82
# 2023-01-24 08:00:00  1134.87   8.61   56.89  80.11  110.63  123.76  140.26
#
#                        nh3
# date
# ...

# %%
AQI.columns
# Out:
# Index(['co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3'], dtype='object')

# %%
plt.figure(figsize=(15,15))
plt.style.use('ggplot')
AQI['no2'].value_counts().plot(kind='pie')
plt.show()

# %%
plt.figure(figsize=(4,5))
plt.style.use('ggplot')
sns.countplot(x='no2',data=AQI)
# Out:
# <AxesSubplot:xlabel='no2', ylabel='count'>

# %%
plt.figure(figsize=(4,5))
plt.style.use('ggplot')
sns.lineplot(x='no2',y='pm10',data=AQI)
# Out:
# <AxesSubplot:xlabel='no2', ylabel='pm10'>

# %%
y=AQI.iloc[:,6]
y
# Out:
# date
# 2020-11-25 01:00:00    411.73
# 2020-11-25 02:00:00    486.21
# 2020-11-25 03:00:00    541.95
# 2020-11-25 04:00:00    534.00
# 2020-11-25 05:00:00    529.19
#                         ...
# 2023-01-24 04:00:00    289.84
# 2023-01-24 05:00:00    280.52
# 2023-01-24 06:00:00    296.07
# 2023-01-24 07:00:00    191.82
# 2023-01-24 08:00:00    140.26
# Name: pm10, Length: 18776, dtype: float64

# %%
x=AQI[['co','no','no2','o3','so2','pm2_5','nh3']]
x
# Out:
#                           co     no     no2     o3     so2   pm2_5    nh3
# date
# 2020-11-25 01:00:00  2616.88   2.18   70.60  13.59   38.62  364.61  28.63
# 2020-11-25 02:00:00  3631.59  23.25   89.11   0.33   54.36  420.96  41.04
# 2020-11-25 03:00:00  4539.49  52.75  100.08   1.11   68.67  463.68  49.14
# 2020-11-25 04:00:00  4539.49  50.96  111.04   6.44   78.20  454.81  48.13
# 2020-11-25 05:00:00  4379.27  42.92  117.90  17.17   87.74  448.14  46.61
# ...                      ...    ...     ...    ...     ...     ...    ...
# 2023-01-24 04:00:00  1762.39   4.64   37.01  33.26   30.52  231.15   6.27
# 2023-01-24 05:00:00  1735.69   6.82   34.96  46.49   34.33  225.08   9.12
# 2023-01-24 06:00:00  1922.61   8.16   40.10  56.51   43.39  242.49  12.54
# 2023-01-24 07:00:00  1361.85   9.05   52.78  71.53  100.14  165.67   7.47
# 2023-01-24 08:00:00  1134.87   8.61   56.89  80.11  110.63  123.76   5.51
#
# [18776 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,
                                                   y,
                                                   test_size=0.20,
                                                   random_state=0)

# %%
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (15020, 7)
# x_test shape: (3756, 7)
# y_train shape: (15020,)
# y_test shape: (3756,)

# %%
x_train
# Out:
#                           co      no     no2      o3    so2   pm2_5    nh3
# date
# 2022-06-14 06:00:00   413.89    0.67   10.88  128.75  19.07   22.11   8.49
# 2020-11-30 03:00:00  5554.20  125.17   74.71    1.48  64.85  393.76  47.12
# 2021-01-31 19:00:00  8224.49  123.38  112.41    0.00  54.36  751.67  29.89
# 2021-08-09 21:00:00  1949.31   15.87   41.13    0.01  22.65  158.84   5.00
# 2022-05-24 16:00:00  1548.77    0.00   52.78   63.66  66.76   96.60  26.85
# ...                      ...     ...     ...     ...    ...     ...    ...
# 2021-12-15 10:00:00  2056.12    9.16   73.34   92.98  63.90  206.89  19.76
# 2022-05-28 20:00:00  1562.12    5.87   47.30    0.64  27.66  107.56  24.83
# 2022-01-10 06:00:00  3177.64   40.68   62.38   32.19  75.34  245.03  22.55
# 2022-02-20 00:00:00   934.60    0.00   20.39   67.95  25.51  118.38   7.09
# 2021-03-19 21:00:00  1321.79    2.38   47.98    2.41  20.27   78.42  21.79
#
# [15020 rows x 7 columns]

# %%
x_test
# Out:
#                           co      no     no2      o3     so2   pm2_5     nh3
# date
# 2022-02-13 02:00:00  5928.04  135.90   66.49    0.01  139.24  479.63  108.42
# 2022-08-04 22:00:00   988.01    7.38   37.01    0.10   56.27   55.05    4.37
# 2022-09-08 19:00:00  1789.09    0.00   60.32   46.49   42.92  186.32   25.08
# 2023-01-07 08:00:00  1535.42    7.60   42.50  114.44   60.56  178.09   11.27
# 2022-09-04 14:00:00   700.95    0.00   31.87   50.78   25.03   22.49   12.54
# ...                      ...     ...     ...     ...     ...     ...     ...
# 2022-07-12 15:00:00  6195.07   92.09  183.70    0.00  177.38  355.51   61.30
# 2022-08-23 12:00:00   460.62    0.81   20.73   80.11   27.18   23.72    6.90
# 2021-01-17 10:00:00  1121.52    3.16   36.67  151.63   81.06  269.77    2.19
# 2022-08-03 10:00:00  1428.60   12.52   58.26   20.38   63.90   53.55   17.48
# 2021-11-01 05:00:00  5714.42   67.06  137.09   41.84   83.92  392.16   47.62
#
# [3756 rows x 7 columns]

# %%
y_test
# Out:
# date
# 2022-02-13 02:00:00    585.29
# 2022-08-04 22:00:00     61.74
# 2022-09-08 19:00:00    227.57
# 2023-01-07 08:00:00    196.41
# 2022-09-04 14:00:00     39.30
#                         ...
# 2022-07-12 15:00:00    465.42
# 2022-08-23 12:00:00     28.61
# 2021-01-17 10:00:00    282.82
# 2022-08-03 10:00:00     74.86
# 2021-11-01 05:00:00    492.94
# Name: pm10, Length: 3756, dtype: float64

# %%
y_train
# Out:
# date
# 2022-06-14 06:00:00     50.57
# 2020-11-30 03:00:00    479.03
# 2021-01-31 19:00:00    911.75
# 2021-08-09 21:00:00    184.69
# 2022-05-24 16:00:00    128.97
#                         ...
# 2021-12-15 10:00:00    240.54
# 2022-05-28 20:00:00    250.55
# 2022-01-10 06:00:00    301.85
# 2022-02-20 00:00:00    131.11
# 2021-03-19 21:00:00    113.60
# Name: pm10, Length: 15020, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
AQI_Predict=LinearRegression()

# %%
AQI_Predict.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m = AQI_Predict. coef_
c = AQI_Predict.intercept_
m,c
# Out:
# (array([ 0.024378  , -0.31621179, -0.19136129,  0.06077659, -0.07398256,
#          0.952271  ,  0.54434972]),
#  12.962293218137347)

# %%
c
# Out:
# 12.962293218137347

# %%
y_predict_train = AQI_Predict.predict(x_train)
y_predict_train
# Out:
# array([ 52.84860885, 490.39389379, 880.97620635, ..., 307.61877649,
#        150.67586617, 120.43610278])

# %%
y_predict_test = AQI_Predict.predict(x_test)
y_predict_test
# Out:
# array([607.23464523,  78.27647822, 235.76340465, ..., 293.59105729,
#         89.70150403, 500.52832312])

# %%
from sklearn.metrics import mean_absolute_error,r2_score

# %%
mean_absolute_error(y_test,y_predict_test)
# Out:
# 20.233647074066152

# %%
mean_absolute_error(y_train,y_predict_train)
# Out:
# 20.398827812427392

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mean_squared_error(y_test,y_predict_test)
# Out:
# 1049.6619452340415

# %%
mean_squared_error(y_train,y_predict_train)
# Out:
# 1092.6091286957273

# %%
accuracy=r2_score(y_test,y_predict_test)

# %%
accuracy
# Out:
# 0.9858844845664998

# %%
print("accuracy is",accuracy*100)
# Out:
# accuracy is 98.58844845664999

# %%
r2score_train= r2_score(y_train, y_predict_train)
r2score_train
# Out:
# 0.9845275420708589

# %%
plt.style.use("default")

plt.figure(figsize=(4, 4))
sns.regplot(x=y_test, y=y_predict_test, ci=None, color="red")
# Out:
# <AxesSubplot:xlabel='pm10'>

# %%
plt.figure(figsize=(4,4))
plt.style.use("ggplot")

plt.scatter(x=range(10),
            y=y_test.head(10),
            color="r",
           label="Actual Points")
plt.scatter(x=range(10),
            y=y_predict_test[:10],
            color="g",
           label="Predicted Points")
plt.legend()

# %%
AQI_Predict=pd.DataFrame({
    "Actual":y_test,
    "Predicted": y_predict_test
 })
print(AQI_Predict)
# Out:
#                      Actual   Predicted
# date
# 2022-02-13 02:00:00  585.29  607.234645
# 2022-08-04 22:00:00   61.74   78.276478
# 2022-09-08 19:00:00  227.57  235.763405
# 2023-01-07 08:00:00  196.41  218.056344
# 2022-09-04 14:00:00   39.30   53.428537
# ...                     ...         ...
# 2022-07-12 15:00:00  465.42  458.500145
# 2022-08-23 12:00:00   28.61   49.170083
# 2021-01-17 10:00:00  282.82  293.591057
# 2022-08-03 10:00:00   74.86   89.701504
# 2021-11-01 05:00:00  492.94  500.528323
#
# [3756 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
plt.subplot(3,3,1)
sns.lineplot(x='no2',y='pm10',data=AQI)

plt.subplot(3,3,2)
sns.lineplot(x='so2',y='pm10',data=AQI)

plt.subplot(3,3,3)
sns.lineplot(x='o3',y='pm10',data=AQI)

plt.subplot(3,3,4)
sns.lineplot(x='co',y='pm10',data=AQI)

plt.show()
